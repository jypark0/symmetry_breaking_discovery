# %%
import torch
from torch import nn
import numpy as np
import random
import matplotlib.pyplot as plt
from relaxed_gconv import TimeRevNet
from utils import Dataset2DTime, train_model_batch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## 1. Generate Pendulum Dataset

# %%
def pendulum_simulator(length, g, beta, theta0, omega0, num_steps, dt, with_friction=True):
    """
    Simulates a pendulum motion with or without friction.

    Args:
    length (float): Length of the pendulum (L).
    g (float): Acceleration due to gravity.
    beta (float): Damping coefficient. Only used if with_friction is True.
    theta0 (float): Initial angular displacement (in radians).
    omega0 (float): Initial angular velocity (in radians per second).
    num_steps (int): Number of simulation steps.
    dt (float): Time step for simulation.
    with_friction (bool): Simulate with friction if True, otherwise simulate without friction.

    Returns:
    numpy.ndarray: Array of shape (num_steps, 2) with [theta, omega] at each time step.
    """
    def damped_pendulum_derivatives(theta, omega):
        """Derivatives for the damped pendulum."""
        return omega, -2 * beta * omega - (g / length) * theta

    def undamped_pendulum_derivatives(theta, omega):
        """Derivatives for the undamped pendulum."""
        return omega, -(g / length) * theta

    # Choose the appropriate derivative function based on whether there's friction
    derivatives_func = damped_pendulum_derivatives if with_friction else undamped_pendulum_derivatives

    # Initialize the array to store [theta, omega] at each step
    results = np.zeros((num_steps, 2))
    theta, omega = theta0, omega0

    for i in range(num_steps):
        results[i] = [theta, omega]

        # Calculate the derivatives
        dtheta, domega = derivatives_func(theta, omega)

        # Update theta and omega using Euler's method
        theta += dtheta * dt
        omega += domega * dt

    return results

# Example parameters for the simulation
length = 1.0  # length of the pendulum in meters
g = 9.81      # acceleration due to gravity in m/s^2
beta = 0.3    # damping coefficient
theta0 = np.pi / 4  # initial angle (45 degrees in radians)
omega0 = 0.0  # initial angular velocity
num_steps = 1000000
dt = 0.00001  # time step

# Simulate both damped and undamped pendulums
undamped_results = pendulum_simulator(length, g, beta, theta0, omega0, num_steps, dt, with_friction=False)
damped_results = pendulum_simulator(length, g, beta, theta0, omega0, num_steps, dt, with_friction=True)

# Display the first few rows of each result for demonstration
undamped = undamped_results[::1000, :1].reshape(1, 1000, 1)
damped = damped_results[::1000, :1].reshape(1, 1000, 1)
np.save("data/pendulum/pendulum_undamped.npy", undamped)
np.save("data/pendulum/pendulum_damped.npy", damped)

plt.plot(undamped[0,:,0], label = "Without Friction", linewidth = 3)
plt.plot(damped[0,:,0], label = "With Friction", linewidth = 3)
plt.xlabel("Time", size = 15)
plt.ylabel("Angle", size = 15.5)
plt.legend(fontsize = 12)
plt.title("Pendulum simulation Without vs. With Friction", size = 17)
plt.show()

# %% [markdown]
# ## 2. Discover Time Reversal Symmetry

# %%
kernel_size = 5
hidden_dim = 4
num_filter_basis = 1
batch_size = 16
learning_rate = 0.001
decay_rate = 0.95
num_epoch = 100
in_channels = 1
out_channels = 1
train_indices = np.arange(0, 800)
valid_indices = np.arange(800, 1000)
length = 8
direc = "data/pendulum/"

all_undamped_weights = []
all_damped_weights = []
for seed in range(10):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    torch.use_deterministic_algorithms(True)
    undamped_train_set = Dataset2DTime(direc = direc + "pendulum_undamped.npy", sample_list = train_indices, length = length)
    undamped_valid_set = Dataset2DTime(direc = direc + "pendulum_undamped.npy", sample_list = valid_indices, length = length)

    undamped_train_loader = torch.utils.data.DataLoader(undamped_train_set, batch_size = batch_size, shuffle = True, num_workers = 0)
    undamped_valid_loader = torch.utils.data.DataLoader(undamped_valid_set, batch_size = batch_size, shuffle = False, num_workers = 0)  

    undamped_model = TimeRevNet(in_channels = in_channels, 
                                out_channels = out_channels, 
                                kernel_size = kernel_size, 
                                hidden_dim = hidden_dim, 
                                num_filter_basis = num_filter_basis).to(device)
    undamped_best_model = train_model_batch(undamped_model, undamped_train_loader, undamped_valid_loader, num_epoch, learning_rate, decay_rate)
    undamped_weights = torch.stack([undamped_best_model.model[i].relaxed_weights for i in range(3)]).cpu().data.numpy()
    all_undamped_weights.append(undamped_weights)

    damped_train_set = Dataset2DTime(direc = direc + "pendulum_damped.npy", sample_list = train_indices, length = length)
    damped_valid_set = Dataset2DTime(direc = direc + "pendulum_damped.npy", sample_list = valid_indices, length = length)

    damped_train_loader = torch.utils.data.DataLoader(damped_train_set, batch_size = batch_size, shuffle = True, num_workers = 0)
    damped_valid_loader = torch.utils.data.DataLoader(damped_valid_set, batch_size = batch_size, shuffle = False, num_workers = 0)  

    damped_model = TimeRevNet(in_channels = in_channels, 
                              out_channels = out_channels, 
                              kernel_size = kernel_size, 
                              hidden_dim = hidden_dim, 
                              num_filter_basis = num_filter_basis).to(device)
    damped_best_model = train_model_batch(damped_model, damped_train_loader, damped_valid_loader, num_epoch, learning_rate, decay_rate)
    damped_weights = torch.stack([damped_best_model.model[i].relaxed_weights for i in range(3)]).cpu().data.numpy()
    all_damped_weights.append(damped_weights)
   
all_damped_weights = np.array(all_damped_weights).transpose(1,0,2,3)
all_undamped_weights = np.array(all_undamped_weights).transpose(1,0,2,3)
# Out:
# Epoch 1 | T: 0.02 | Train MAE: 0.27987 | Valid MAE: 0.17667 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.01716 | Valid MAE: 0.01718 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00871 | Valid MAE: 0.00825 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00387 | Valid MAE: 0.00348 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00166 | Valid MAE: 0.00158 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00132 | Valid MAE: 0.00125 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00115 | Valid MAE: 0.00110 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00108 | Valid MAE: 0.00103 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00103 | Valid MAE: 0.00099 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00100 | Valid MAE: 0.00096 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05409 | Valid MAE: 0.09649 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00391 | Valid MAE: 0.01088 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00248 | Valid MAE: 0.00693 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00212 | Valid MAE: 0.00606 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00196 | Valid MAE: 0.00561 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00178 | Valid MAE: 0.00507 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00158 | Valid MAE: 0.00449 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00141 | Valid MAE: 0.00401 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00129 | Valid MAE: 0.00367 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00121 | Valid MAE: 0.00346 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.26253 | Valid MAE: 0.16022 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.01131 | Valid MAE: 0.01087 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.01101 | Valid MAE: 0.01058 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.01080 | Valid MAE: 0.01038 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.01065 | Valid MAE: 0.01024 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.01052 | Valid MAE: 0.01012 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.01043 | Valid MAE: 0.01003 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.01036 | Valid MAE: 0.00997 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.01031 | Valid MAE: 0.00992 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.01028 | Valid MAE: 0.00989 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05433 | Valid MAE: 0.08693 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00373 | Valid MAE: 0.01023 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00194 | Valid MAE: 0.00525 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00180 | Valid MAE: 0.00489 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00170 | Valid MAE: 0.00463 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00162 | Valid MAE: 0.00439 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00154 | Valid MAE: 0.00418 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00147 | Valid MAE: 0.00400 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00142 | Valid MAE: 0.00385 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00138 | Valid MAE: 0.00375 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.27083 | Valid MAE: 0.17431 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.01398 | Valid MAE: 0.01288 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00408 | Valid MAE: 0.00353 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00173 | Valid MAE: 0.00166 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00158 | Valid MAE: 0.00152 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00135 | Valid MAE: 0.00129 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00122 | Valid MAE: 0.00117 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00111 | Valid MAE: 0.00106 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00106 | Valid MAE: 0.00102 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00102 | Valid MAE: 0.00098 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05259 | Valid MAE: 0.10286 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00344 | Valid MAE: 0.00938 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00228 | Valid MAE: 0.00655 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00223 | Valid MAE: 0.00640 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00219 | Valid MAE: 0.00631 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00217 | Valid MAE: 0.00625 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00216 | Valid MAE: 0.00621 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00215 | Valid MAE: 0.00618 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00214 | Valid MAE: 0.00616 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00213 | Valid MAE: 0.00614 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.28817 | Valid MAE: 0.21484 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.01078 | Valid MAE: 0.01152 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00322 | Valid MAE: 0.00298 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00170 | Valid MAE: 0.00164 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00142 | Valid MAE: 0.00136 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00130 | Valid MAE: 0.00125 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00124 | Valid MAE: 0.00119 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00120 | Valid MAE: 0.00115 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00113 | Valid MAE: 0.00109 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00111 | Valid MAE: 0.00107 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05538 | Valid MAE: 0.08363 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00385 | Valid MAE: 0.01063 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00116 | Valid MAE: 0.00282 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00043 | Valid MAE: 0.00116 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00037 | Valid MAE: 0.00101 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00035 | Valid MAE: 0.00096 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00034 | Valid MAE: 0.00094 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00034 | Valid MAE: 0.00092 | LR 0.000026
# Epoch 1 | T: 0.00 | Train MAE: 0.26021 | Valid MAE: 0.14736 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.01278 | Valid MAE: 0.01166 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00914 | Valid MAE: 0.00870 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00630 | Valid MAE: 0.00587 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00242 | Valid MAE: 0.00223 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00150 | Valid MAE: 0.00144 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00128 | Valid MAE: 0.00123 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00115 | Valid MAE: 0.00111 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00109 | Valid MAE: 0.00105 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00105 | Valid MAE: 0.00101 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05198 | Valid MAE: 0.06795 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00381 | Valid MAE: 0.01050 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00138 | Valid MAE: 0.00350 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00046 | Valid MAE: 0.00125 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00041 | Valid MAE: 0.00112 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00038 | Valid MAE: 0.00103 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00036 | Valid MAE: 0.00099 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00036 | Valid MAE: 0.00097 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00035 | Valid MAE: 0.00096 | LR 0.000016
# Epoch 1 | T: 0.00 | Train MAE: 0.25771 | Valid MAE: 0.18177 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.15417 | Valid MAE: 0.17138 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.15357 | Valid MAE: 0.17104 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.15340 | Valid MAE: 0.17089 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.15334 | Valid MAE: 0.17083 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.15330 | Valid MAE: 0.17079 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.15327 | Valid MAE: 0.17076 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.15325 | Valid MAE: 0.17074 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.15324 | Valid MAE: 0.17073 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.15323 | Valid MAE: 0.17072 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05715 | Valid MAE: 0.10800 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00383 | Valid MAE: 0.01061 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00222 | Valid MAE: 0.00632 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00205 | Valid MAE: 0.00586 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00190 | Valid MAE: 0.00541 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00166 | Valid MAE: 0.00471 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00137 | Valid MAE: 0.00388 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00114 | Valid MAE: 0.00322 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00099 | Valid MAE: 0.00281 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00091 | Valid MAE: 0.00257 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.25183 | Valid MAE: 0.12226 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.01141 | Valid MAE: 0.01092 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.01047 | Valid MAE: 0.01002 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00925 | Valid MAE: 0.00881 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00697 | Valid MAE: 0.00656 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00415 | Valid MAE: 0.00388 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00266 | Valid MAE: 0.00253 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00219 | Valid MAE: 0.00210 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00202 | Valid MAE: 0.00194 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00194 | Valid MAE: 0.00187 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05892 | Valid MAE: 0.11681 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00383 | Valid MAE: 0.01060 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00162 | Valid MAE: 0.00424 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00044 | Valid MAE: 0.00119 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00037 | Valid MAE: 0.00102 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00035 | Valid MAE: 0.00097 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00034 | Valid MAE: 0.00094 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00034 | Valid MAE: 0.00093 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00033 | Valid MAE: 0.00092 | LR 0.000016
# Epoch 1 | T: 0.00 | Train MAE: 0.27610 | Valid MAE: 0.16877 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.01737 | Valid MAE: 0.01775 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00460 | Valid MAE: 0.00428 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00164 | Valid MAE: 0.00160 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00137 | Valid MAE: 0.00134 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00120 | Valid MAE: 0.00117 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00111 | Valid MAE: 0.00108 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00106 | Valid MAE: 0.00103 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00101 | Valid MAE: 0.00098 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00098 | Valid MAE: 0.00095 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05686 | Valid MAE: 0.10332 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00225 | Valid MAE: 0.00607 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00218 | Valid MAE: 0.00592 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00214 | Valid MAE: 0.00583 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00212 | Valid MAE: 0.00576 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00210 | Valid MAE: 0.00571 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00209 | Valid MAE: 0.00568 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00208 | Valid MAE: 0.00566 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00207 | Valid MAE: 0.00564 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00207 | Valid MAE: 0.00563 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.25879 | Valid MAE: 0.11263 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.01455 | Valid MAE: 0.01393 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00206 | Valid MAE: 0.00193 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00157 | Valid MAE: 0.00151 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00145 | Valid MAE: 0.00139 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00139 | Valid MAE: 0.00134 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00135 | Valid MAE: 0.00130 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00133 | Valid MAE: 0.00128 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00131 | Valid MAE: 0.00126 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00128 | Valid MAE: 0.00124 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05368 | Valid MAE: 0.08959 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00377 | Valid MAE: 0.01044 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00225 | Valid MAE: 0.00638 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00177 | Valid MAE: 0.00498 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00099 | Valid MAE: 0.00272 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00055 | Valid MAE: 0.00153 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00045 | Valid MAE: 0.00125 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00042 | Valid MAE: 0.00116 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00040 | Valid MAE: 0.00112 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00040 | Valid MAE: 0.00109 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.23159 | Valid MAE: 0.11195 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.01167 | Valid MAE: 0.01150 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00218 | Valid MAE: 0.00207 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00189 | Valid MAE: 0.00185 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00183 | Valid MAE: 0.00178 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00178 | Valid MAE: 0.00174 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00171 | Valid MAE: 0.00167 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00167 | Valid MAE: 0.00162 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00161 | Valid MAE: 0.00156 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00158 | Valid MAE: 0.00154 | LR 0.000009
# Epoch 1 | T: 0.00 | Train MAE: 0.05649 | Valid MAE: 0.10641 | LR 0.000950
# Epoch 11 | T: 0.00 | Train MAE: 0.00249 | Valid MAE: 0.00708 | LR 0.000569
# Epoch 21 | T: 0.00 | Train MAE: 0.00232 | Valid MAE: 0.00666 | LR 0.000341
# Epoch 31 | T: 0.00 | Train MAE: 0.00227 | Valid MAE: 0.00652 | LR 0.000204
# Epoch 41 | T: 0.00 | Train MAE: 0.00224 | Valid MAE: 0.00644 | LR 0.000122
# Epoch 51 | T: 0.00 | Train MAE: 0.00222 | Valid MAE: 0.00639 | LR 0.000073
# Epoch 61 | T: 0.00 | Train MAE: 0.00220 | Valid MAE: 0.00634 | LR 0.000044
# Epoch 71 | T: 0.00 | Train MAE: 0.00219 | Valid MAE: 0.00632 | LR 0.000026
# Epoch 81 | T: 0.00 | Train MAE: 0.00219 | Valid MAE: 0.00630 | LR 0.000016
# Epoch 91 | T: 0.00 | Train MAE: 0.00218 | Valid MAE: 0.00629 | LR 0.000009

# %%
ticks = ['Layer 1', 'Layer 2', 'Layer 3']
def define_box_properties(plot_name, color_code, label, leg = False):
    for k, v in plot_name.items():
        plt.setp(plot_name.get(k), color=color_code)
         
    # use plot function to draw a small line to name the legend.
    plt.plot([], c=color_code, label=label)
    if leg:
        plt.legend(fontsize = 12)
        
max_lim = np.max([np.max(all_undamped_weights), np.max(all_damped_weights)])
min_lim = np.min([np.min(all_undamped_weights), np.min(all_damped_weights)])
space = (max_lim - min_lim)/10

plt.subplot(1,2,1)
summer_rain = list(all_undamped_weights[:,:,:,0].mean(-1))
winter_rain = list(all_undamped_weights[:,:,:,1].mean(-1))
 
summer_rain_plot = plt.boxplot(summer_rain,
                               positions=np.array(
    np.arange(len(summer_rain)))*2.0-0.35, 
                               widths=0.6)
winter_rain_plot = plt.boxplot(winter_rain,
                               positions=np.array(
    np.arange(len(winter_rain)))*2.0+0.35,
                               widths=0.6)
 
# setting colors for each groups
define_box_properties(summer_rain_plot, '#D7191C', '+1', leg = True)
define_box_properties(winter_rain_plot, '#2C7BB6', '-1', leg = True)
 
# set the x label values
plt.xticks(np.arange(0, len(ticks) * 2, 2), ticks)
 
# set the limit for x axis
plt.xlim(-2, len(ticks)*2)

# set the limit for y axis
# plt.ylim(0.77, 1.1)
plt.ylim(min_lim-space, max_lim+space)
# set the title
plt.title('Without Friction (Energy Conserved)', size = 11)

plt.subplot(1,2,2)
summer_rain = list(all_damped_weights[:,:,:,0].mean(-1))
winter_rain = list(all_damped_weights[:,:,:,1].mean(-1))
 
summer_rain_plot = plt.boxplot(summer_rain,
                               positions=np.array(
    np.arange(len(summer_rain)))*2.0-0.35, 
                               widths=0.6)
winter_rain_plot = plt.boxplot(winter_rain,
                               positions=np.array(
    np.arange(len(winter_rain)))*2.0+0.35,
                               widths=0.6)
 
# setting colors for each groups
define_box_properties(summer_rain_plot, '#D7191C', '+1', leg = False)
define_box_properties(winter_rain_plot, '#2C7BB6', '-1', leg = False)
 
# set the x label values
plt.xticks(np.arange(0, len(ticks) * 2, 2), ticks)
 
# set the limit for x axis
plt.xlim(-2, len(ticks)*2)


# set the limit for y axis
# plt.ylim(0.77, 1.1)
plt.ylim(min_lim-space, max_lim+space)
plt.yticks([])
plt.title('With Friction', size = 11)
plt.suptitle('Relaxed Weights for Time Reversal Symmetry of Pendulum', size = 14)
# Out:
# Text(0.5, 0.98, 'Relaxed Weights for Time Reversal Symmetry of Pendulum')
